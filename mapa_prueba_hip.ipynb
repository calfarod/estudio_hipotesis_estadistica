# %% [markdown]
# # Mapa de Decisión para Prueba de Hipótesis

# %% [markdown]
# ```markdown
# ¿QUÉ TIPO DE VARIABLE DESEAS ANALIZAR?
#                                                    │
#         ┌──────────────────────────────────────────┴──────────────────────────────────────────┐
#         ▼                                                                                     ▼
#   CUANTITATIVA (Métrica)                                                            CUALITATIVA (Categoría / %)
#   Ej: Gasto ($), Satisfacción (1-100), Tiempo (min)                                 Ej: Preferencia (Sí/No), Marca elegida
#         │                                                                                     │
#         ├─────────────────────────────┬─────────────────────────────┐                         ├─────────────────────────────┐
#         ▼                             ▼                             ▼                         ▼                             ▼
#    1 MUESTRA                     2 MUESTRAS                    > 2 MUESTRAS               1 MUESTRA                    2 O MÁS MUESTRAS
# (Comparar vs. Estándar)      (Comparar 2 Grupos)            (Comparar 3+ Grupos)       (Comparar % actual vs. Meta)  (Relación entre categorías)
#         │                             │                             │                         │                             │
#   Prueba t para 1 muestra       ¿Son independientes            ANOVA de 1 Vía           Prueba Z para 1 Proporción   Prueba Chi-Cuadrado (χ²)
#  (Ej: Caso 1: ¿La satisfacción   o relacionadas?               (Ej: Probar gasto medio   (Ej: ¿El % de adopción       de Independencia
#   media es igual a 80?)               │                        en 4 sucursales distintas) del nuevo producto pasó    (Ej: ¿La preferencia de marca
#                                       ├──────────────────┐                                  de 20% a 30%?)         depende de la edad?)
#                                       ▼                  ▼
#                               INDEPENDIENTES         PAREADAS
#                             (Grupos distintos)   (Mismo grupo, Pre/Post)
#                                       │                  │
#                              Prueba t para 2        Prueba t para Muestras
#                              Muestras Indep.        Emparejadas / Repetidas
#                             (Ej: Comparar gasto    (Ej: Satisfacción ANTES y
#                              de Hombres vs.         DESPUÉS de una campaña)
#                              Mujeres)
# ```
